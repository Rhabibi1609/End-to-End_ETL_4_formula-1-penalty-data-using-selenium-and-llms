# %%
import pandas as pd

# %%
# Load your CSV file
df = pd.read_csv(r"csv file location")

# %%
# Print basic info about the dataframe
print("=== DataFrame Info ===")
print(df.info())
print("\n")
# Out:
# === DataFrame Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1173 entries, 0 to 1172
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   type_of_document            1172 non-null   object
#  1   year                        1158 non-null   object
#  2   grand_prix                  1170 non-null   object
#  3   description                 1170 non-null   object
#  4   session_type                461 non-null    object
#  5   track                       654 non-null    object
#  6   lap_number                  18 non-null     object
#  7   turn_number                 101 non-null    object
#  8   safety_car_or_vsc_involved  22 non-null     object
#  9   penalty_given               280 non-null    object
#  10  type_of_incident            430 non-null    object
#  11  was_contact_made            117 non-null    object
#  12  immediat_advantage_gained   5 non-null      object
#  13  drivers_invovled            803 non-null    object
#  14  teams_invovled              731 non-null    object
#  15  rule_violated               587 non-null    object
#  16  decision_notes              1056 non-null   object
#  17  source_file                 952 non-null    object
# dtypes: object(18)
# memory usage: 165.1+ KB
# None

# %%
# Show first few rows
print("=== Sample Rows ===")
print(df.head())
print("\n")
# Out:
# === Sample Rows ===
#                                     type_of_document  \
# 0                                         Document 3
# 1  {'Yuki Tsunoda': {'Brazil': 12, 'Canada': 8, '...
# 2                          Technical delegate report
# 3                        Technical Delegate's Report
# 4                                  Stewards Decision
#
#                                                 year  \
# 0                                               2022
# 1  {'Oracle Red Bull': {'Brazil': 18, 'Canada': 1...
# 2                                               2022
# 3                                               2022
# 4                                               2022
#
#                                           grand_prix  \
# 0                               Abu Dhabi Grand Prix
# 1  2022 Abu Dhabi Grand Prix - Championship Point...
# 2                               Abu Dhabi Grand Prix
# 3                               Abu Dhabi Grand Prix
# 4                               Abu Dhabi Grand Prix
#
#                                          description session_type  \
# 0                              Car Display Procedure          NaN
# 1                                                NaN          NaN
# 2  Two team personnel of the McLaren and Alfa Rom...          NaN
# 3  Oracle Red Bull Racing team and BWT Alpine F1 ...          NaN
# 4  Driver Lewis Hamilton of Mercedes-AMG Petronas...   Practice 3
#
#                 track lap_number turn_number safety_car_or_vsc_involved  \
# 0           Abu Dhabi        NaN         NaN                        NaN
# 1                 NaN        NaN         NaN                        NaN
# 2  Yas Marina Circuit        NaN         NaN                        NaN
# 3                 NaN        NaN         NaN                        NaN
# 4                 NaN        NaN         NaN                        NaN
#
#   penalty_given                   type_of_incident was_contact_made  \
# 0           NaN              Car Display Procedure              NaN
# 1           NaN                                NaN              NaN
# 2           NaN  Exceeding a temporary restriction              NaN
# 3           NaN                                NaN              NaN
# 4           NaN          Overtaking under red flag              NaN
#
#   immediat_advantage_gained                      drivers_invovled  \
# 0                       NaN                                   NaN
# 1                       NaN                                   NaN
# 2                       NaN             ['Alfa Romeo', 'McLaren']
# 3                       NaN                                   NaN
# 4                       NaN  ['Lewis Hamilton', 'Max Verstappen']
#
#                                      teams_invovled  \
# 0                                               NaN
# 1                                               NaN
# 2   ['McLaren F1 Team', 'Alfa Romeo F1 Team ORLEN']
# 3  ['Oracle Red Bull Racing', 'BWT Alpine F1 Team']
# 4                 ['Mercedes-AMG Petronas F1 Team']
#
#                                        rule_violated  \
# 0  Article 19 of the FIA Formula One Sporting Reg...
# 1                                                NaN
# 2                                       Article 27.1
# 3                                                NaN
# 4  Appendix L Ch IV Art 1, Appendix H 2.5.4.1.b o...
#
#                                       decision_notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  First of two individual exceptions permitted f...
# 4  The Stewards determined no penalty would be ap...
#
#                                          source_file
# 0  2022 Abu Dhabi Grand Prix - Car Display Proced...
# 1                                                NaN
# 2             2022 Abu Dhabi Grand Prix - Curfew.txt
# 3           2022 Abu Dhabi Grand Prix - Curfew_0.txt
# 4  2022 Abu Dhabi Grand Prix - Decision - Car 44 ...

# %%
# Check missing values per column
print("=== Missing Values Per Column ===")
print(df.isnull().sum())
print("\n")
# Out:
# === Missing Values Per Column ===
# type_of_document                 1
# year                            15
# grand_prix                       3
# description                      3
# session_type                   712
# track                          519
# lap_number                    1155
# turn_number                   1072
# safety_car_or_vsc_involved    1151
# penalty_given                  893
# type_of_incident               743
# was_contact_made              1056
# immediat_advantage_gained     1168
# drivers_invovled               370
# teams_invovled                 442
# rule_violated                  586
# decision_notes                 117
# source_file                    221
# dtype: int64

# %%
# Describe object columns: number of unique values and examples
print("=== Feature Details ===")
for col in df.columns:
    print(f"\n--- {col} ---")
    print(f"Type: {df[col].dtype}")
    num_unique = df[col].nunique(dropna=True)
    print(f"Unique values: {num_unique}")
    # Show example values
    examples = df[col].dropna().unique()[:5]
    print(f"Examples: {examples}")
    num_missing = df[col].isnull().sum()
    print(f"Missing values: {num_missing}")
# Out:
# === Feature Details ===
#
# --- type_of_document ---
# Type: object
# Unique values: 82
# Examples: ['Document 3'
#  "{'Yuki Tsunoda': {'Brazil': 12, 'Canada': 8, 'China': 11, 'France': 15, 'Hungary': 10, 'Italy': 17, 'Japan': 13, 'Mexico': 14, 'Qatar': 16}, 'Guanyu Zhou': {'Brazil': 6, 'Canada': 11, 'China': 15, 'France': 10, 'Hungary': 9, 'Italy': 8, 'Japan': 13, 'Mexico': 12, 'Qatar': 16}, 'Alex Albon': {'Brazil': 4, 'Canada': 14, 'China': 10, 'France': 11, 'Hungary': 8, 'Italy': 12, 'Japan': 5, 'Mexico': 13, 'Qatar': 15}, 'Nick Latifi': {'Brazil': 2, 'Canada': 16, 'China': 16, 'France': 14, 'Hungary': 15, 'Italy': 15, 'Japan': 17, 'Mexico': 18, 'Qatar': 19}, 'Nyck de Vries': {'Brazil': 9, 'Canada': 0, 'China': 12, 'France': 17, 'Hungary': 8, 'Italy': 9, 'Japan': 10, 'Mexico': 11, 'Qatar': 18}, 'Nico Hulkenberg': {'Brazil': 17, 'Canada': 12, 'China': 0, 'France': 0, 'Hungary': 0, 'Italy': 0, 'Japan': 0, 'Mexico': 0, 'Qatar': 0}, 'Yves Menard': {'Brazil': 0, 'Canada': 0, 'China': 0, 'France': 0, 'Hungary': 0, 'Italy': 0, 'Japan': 0, 'Mexico': 0, 'Qatar': 0}, 'Nico Laisnez': {'Brazil': 0, 'Canada': 0, 'China': 0, 'France': 0, 'Hungary': 0, 'Italy': 0, 'Japan': 0, 'Mexico': 0, 'Qatar': 0}}"
#  'Technical delegate report' "Technical Delegate's Report"
#  'Stewards Decision']
# Missing values: 1
#
# --- year ---
# Type: object
# Unique values: 22
# Examples: ['2022'
#  "{'Oracle Red Bull': {'Brazil': 18, 'Canada': 1, 'China': 2, 'France': 2, 'Hungary': 1, 'Italy': 3, 'Japan': 2, 'Mexico': 4, 'Qatar': 5}, 'Racing': {'Brazil': 19, 'Canada': 4, 'China': 33, 'France': 26, 'Hungary': 44, 'Italy': 30, 'Japan': 40, 'Mexico': 38, 'Qatar': 43}, 'Scuderia Ferrari': {'Brazil': 2, 'Canada': 5, 'China': 6, 'France': 8, 'Hungary': 12, 'Italy': 16, 'Japan': 14, 'Mexico': 10, 'Qatar': 11}, 'Mercedes-AMG': {'Brazil': 3, 'Canada': 5, 'China': 4, 'France': 7, 'Hungary': 9, 'Italy': 14, 'Japan': 10, 'Mexico': 11, 'Qatar': 8}, 'BWT Alpine F1 Team': {'Brazil': 7, 'Canada': 6, 'China': 7, 'France': 5, 'Hungary': 14, 'Italy': 11, 'Japan': 9, 'Mexico': 8, 'Qatar': 4}, 'McLaren F1 Team': {'Brazil': 14, 'Canada': 7, 'China': 5, 'France': 6, 'Hungary': 13, 'Italy': 9, 'Japan': 8, 'Mexico': 11, 'Qatar': 16}, 'Alfa Romeo F1 Team': {'Brazil': 6, 'Canada': 11, 'China': 15, 'France': 13, 'Hungary': 14, 'Italy': 17, 'Japan': 12, 'Mexico': 10, 'Qatar': 9}, 'Aston Martin Aramco': {'Brazil': 7, 'Canada': 12, 'China': 12, 'France': 11, 'Hungary': 10, 'Italy': 10, 'Japan': 11, 'Mexico': 9, 'Qatar': 8}, 'Cognizant F1 Team': {'Brazil': 17, 'Canada': 13, 'China': 10, 'France': 17, 'Hungary': 15, 'Italy': 12, 'Japan': 11, 'Mexico': 11, 'Qatar': 8}, 'Haas F1 Team': {'Brazil': 5, 'Canada': 9, 'China': 13, 'France': 14, 'Hungary': 16, 'Italy': 15, 'Japan': 14, 'Mexico': 12, 'Qatar': 16}, 'Scuderia AlphaTauri': {'Brazil': 8, 'Canada': 8, 'China': 9, 'France': 11, 'Hungary': 10, 'Italy': 12, 'Japan': 14, 'Mexico': 13, 'Qatar': 17}, 'Williams Racing': {'Brazil': 8, 'Canada': 13, 'China': 16, 'France': 11, 'Hungary': 15, 'Italy': 12, 'Japan': 16, 'Mexico': 14, 'Qatar': 18}}"
#  'FIA Formula One Race Director'
#  "{'Oracle Red Bull Racing': {'1': 'Max Verstappen', '19': 'Sergio Perez'}, 'Scuderia Ferrari': {'2': 'Charles Leclerc', '27': 'Carlos Sainz Jr.'}, 'Mercedes-AMG Petronas F1 Team': {'3': 'Lewis Hamilton', '4': 'George Russell'}, 'BWT Alpine F1 Team': {'5': 'Esteban Ocon', '6': 'Pierre Gasly'}, 'McLaren F1 Team': {'7': 'Lando Norris', '15': 'Daniel Ricciardo'}, 'Alfa Romeo Racing Orlen': {'8': 'Valtteri Bottas', '9': 'Robert Kubica'}, 'Aston Martin Cognizant F1 Team': {'10': 'Sebastian Vettel', '11': 'Lance Stroll'}, 'Haas F1 Team': {'8': 'Mick Schumacher', '9': 'Kevin Magnussen'}, 'Scuderia AlphaTauri': {'9': 'Daniel Hahnel', '10': 'Yuki Tsunoda'}, 'Williams Racing': {'16': 'Alex Albon', '21': 'Nyck de Vries'}}"
#  '346']
# Missing values: 15
#
# --- grand_prix ---
# Type: object
# Unique values: 38
# Examples: ['Abu Dhabi Grand Prix'
#  '2022 Abu Dhabi Grand Prix - Championship Points.txt'
#  'Australian Grand Prix' 'Austrian Grand Prix' 'Azerbaijan Grand Prix']
# Missing values: 3
#
# --- description ---
# Type: object
# Unique values: 1034
# Examples: ['Car Display Procedure'
#  'Two team personnel of the McLaren and Alfa Romeo teams were within the circuit during a thirteen hour period before the start time.'
#  'Oracle Red Bull Racing team and BWT Alpine F1 Team personnel were within the circuit during a restricted period.'
#  'Driver Lewis Hamilton of Mercedes-AMG Petronas F1 Team was found to have breached Appendix L Ch IV Art 1, Appendix H 2.5.4.1.b of the FIA International Sporting Code during Practice 3.'
#  'Entry List and Additional drivers allowed for P1 according to Article 32.4 of the FIA Formula One Sporting Regulations.']
# Missing values: 3
#
# --- session_type ---
# Type: object
# Unique values: 65
# Examples: ['Practice 3' 'Qualifying' ' scrutineering' 'Reconnaissance Laps' 'Race']
# Missing values: 712
#
# --- track ---
# Type: object
# Unique values: 97
# Examples: ['Abu Dhabi' 'Yas Marina Circuit' 'Albert Park Circuit'
#  'Altona Street Circuit' 'Melbourne']
# Missing values: 519
#
# --- lap_number ---
# Type: object
# Unique values: 15
# Examples: ['7' '16' '17' '51'
#  "[{'title': 'Tyres notes', 'text': '• Not permitted to switch tyres from their originally allocated position. • Heating time temperature limits apply to the actual tyre surface temperature measured with the IR gun as detailed in TD003. • Do not subject tyres to large deformation or heavy impact.'}]"]
# Missing values: 1155
#
# --- turn_number ---
# Type: object
# Unique values: 50
# Examples: ['T1' '3' '13' '2' '14']
# Missing values: 1072
#
# --- safety_car_or_vsc_involved ---
# Type: object
# Unique values: 7
# Examples: ['Yes' 'True' 'Safety Car' 'Pit Lane Starts'
#  'SAFETY CAR Line 2, PIT LANE Starts PIT LANE Ends, SAFETY CAR Line 1, F1 Garages']
# Missing values: 1151
#
# --- penalty_given ---
# Type: object
# Unique values: 160
# Examples: ["5 second time penalty - Causing a collision - Stewards' document no. 33"
#  'Grid penalty (3 places)' '€500'
#  '5 second time penalty, 2 penalty points (total of 3 for the 12 month period)'
#  '5 seconds']
# Missing values: 893
#
# --- type_of_incident ---
# Type: object
# Unique values: 263
# Examples: ['Car Display Procedure' 'Exceeding a temporary restriction'
#  'Overtaking under red flag' 'Causing a collision' 'Speeding in pit lane']
# Missing values: 743
#
# --- was_contact_made ---
# Type: object
# Unique values: 12
# Examples: ['Yes' 'True' 'False' "['Alexander Albon']" 'true']
# Missing values: 1056
#
# --- immediat_advantage_gained ---
# Type: object
# Unique values: 5
# Examples: ["['Williams Racing']" 'Yes, by completing the pass off track'
#  'Gaining a lasting advantage by leaving the track at turn 14' 'yes'
#  '2022 Saudi Arabian Grand Prix - Offence - Car 24 - leaving the track and gaining an advantage.txt']
# Missing values: 1168
#
# --- drivers_invovled ---
# Type: object
# Unique values: 477
# Examples: ["['Alfa Romeo', 'McLaren']" "['Lewis Hamilton', 'Max Verstappen']"
#  "['George Russell', 'Lewis Hamilton', 'Max Verstappen', 'Sergio Perez', 'Charles Leclerc', 'Carlos Sainz', 'Daniel Ricciardo', 'Lando Norris', 'Fernando Alonso', 'Esteban Ocon', 'Pierre Gasly', 'Yuki Tsunoda', 'Lance Stroll', 'Sebastian Vettel', 'Alexander Albon', 'Nicholas Latifi', 'Valtteri Bottas', 'Zhou Guanyu', 'Kevin Magnussen', 'Mick Schumacher']"
#  "['Ferrari', 'Haas', 'Williams', 'Aston Martin', 'Alpine', 'McLaren']"
#  "['Max VERSTAPPEN', 'Sergio PEREZ']"]
# Missing values: 370
#
# --- teams_invovled ---
# Type: object
# Unique values: 280
# Examples: ["['McLaren F1 Team', 'Alfa Romeo F1 Team ORLEN']"
#  "['Oracle Red Bull Racing', 'BWT Alpine F1 Team']"
#  "['Mercedes-AMG Petronas F1 Team']"
#  "['Mercedes-AMG Petronas F1 Team', 'Oracle Red Bull Racing', 'Scuderia Ferrari', 'McLaren F1 Team', 'BWT Alpine F1 Team', 'Williams Racing', 'Aston Martin Aramco Cognizant F1 Team', 'Alfa Romeo F1 Team ORLEN']"
#  "['McLaren F1 Team', 'Scuderia AlphaTauri']"]
# Missing values: 442
#
# --- rule_violated ---
# Type: object
# Unique values: 306
# Examples: ['Article 19 of the FIA Formula One Sporting Regulations' 'Article 27.1'
#  'Appendix L Ch IV Art 1, Appendix H 2.5.4.1.b of the FIA International Sporting Code'
#  'Pit lane and safety car information'
#  'Pole position lap: Max VERSTAPPEN Oracle Red Bull Racing 1:23.824, Fastest lap: Max VERSTAPPEN Oracle Red Bull Racing 1:23.824']
# Missing values: 586
#
# --- decision_notes ---
# Type: object
# Unique values: 885
# Examples: ['First of two individual exceptions permitted for the Oracle Red Bull Racing team and BWT Alpine F1 Team during the 2022 Formula One Championship season.'
#  'The Stewards determined no penalty would be applied as the driver took every reasonable action to comply with the regulations.'
#  'Article 32.4 of the FIA Formula One Sporting Regulations.'
#  '2022 Abu Dhabi Grand Prix - Event Notes - Circuit Map, Pit Lane Drawing and Red Zone.txt'
#  'Prescriptions for tyre operation during the event, including prescriptions and notes on temperature limits and heating times.']
# Missing values: 117
#
# --- source_file ---
# Type: object
# Unique values: 948
# Examples: ['2022 Abu Dhabi Grand Prix - Car Display Procedure.txt'
#  '2022 Abu Dhabi Grand Prix - Curfew.txt'
#  '2022 Abu Dhabi Grand Prix - Curfew_0.txt'
#  '2022 Abu Dhabi Grand Prix - Decision - Car 44 - Red Flag_0.txt'
#  '2022 Abu Dhabi Grand Prix - Entry List.txt']
# Missing values: 221

# %%
# Optional: List columns with a high proportion of missing data
print("\n=== Columns with >50% missing data ===")
missing_ratio = df.isnull().mean()
print(missing_ratio[missing_ratio > 0.5])
# Out:
# === Columns with >50% missing data ===
# session_type                  0.606991
# lap_number                    0.984655
# turn_number                   0.913896
# safety_car_or_vsc_involved    0.981245
# penalty_given                 0.761296
# type_of_incident              0.633419
# was_contact_made              0.900256
# immediat_advantage_gained     0.995737
# dtype: float64

# %%
# Optional: Save a summary table to CSV
summary = pd.DataFrame({
    'Type': df.dtypes,
    'Unique Values': df.nunique(),
    'Missing Values': df.isnull().sum(),
    'Missing %': df.isnull().mean() * 100
})
summary.to_csv("feature_summary.csv")

print("\nFeature summary saved to 'feature_summary.csv'")
# Out:
# Feature summary saved to 'feature_summary.csv'

# %%
penalty_df = df[
    df['penalty_given'].notnull() &
    df['description'].notnull() 
    
].copy()


print("\n=== Penalty DataFrame Info ===")
print(penalty_df.info())
print(penalty_df)
penalty_df.to_csv("penalty22_data.csv", index=False)
# Out:
# === Penalty DataFrame Info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 280 entries, 9 to 1156
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   type_of_document            280 non-null    object
#  1   year                        272 non-null    object
#  2   grand_prix                  278 non-null    object
#  3   description                 280 non-null    object
#  4   session_type                215 non-null    object
#  5   track                       94 non-null     object
#  6   lap_number                  10 non-null     object
#  7   turn_number                 57 non-null     object
#  8   safety_car_or_vsc_involved  6 non-null      object
#  9   penalty_given               280 non-null    object
#  10  type_of_incident            225 non-null    object
#  11  was_contact_made            50 non-null     object
#  12  immediat_advantage_gained   5 non-null      object
#  13  drivers_invovled            275 non-null    object
#  14  teams_invovled              262 non-null    object
#  15  rule_violated               217 non-null    object
#  16  decision_notes              257 non-null    object
#  17  source_file                 254 non-null    object
# dtypes: object(18)
# memory usage: 41.6+ KB
# None
#                                        type_of_document  year  \
# 9                                    Stewards' document  2022
# 10                                    Stewards decision  2022
# 12                                    Stewards decision  2022
# 13                                    Stewards Decision  2022
# 14                                    Stewards decision  2022
# ...                                                 ...   ...
# 1139                                 Steward's decision  2022
# 1152  Stewards' decision / Provisional race classifi...  2022
# 1153                                 Stewards' decision  2022
# 1155                                  Stewards decision  2022
# 1156                                 Stewards' decision  2022
#
#                     grand_prix  \
# 9         Abu Dhabi Grand Prix
# 10        Abu Dhabi Grand Prix
# 12        Abu Dhabi Grand Prix
# 13        Abu Dhabi Grand Prix
# 14        Abu Dhabi Grand Prix
# ...                        ...
# 1139  United States Grand Prix
# 1152  United States Grand Prix
# 1153  United States Grand Prix
# 1155  United States Grand Prix
# 1156  United States Grand Prix
#
#                                             description         session_type  \
# 9     Final Race Classification after 58 Laps - 306....                  NaN
# 10    Penalty given to Daniel Ricciardo for causing ...                  NaN
# 12    Driver Lewis Hamilton fined €500 for speeding ...  Reconnaissance Laps
# 13    Collision between Car 47 and Car 6, breach of ...                 Race
# 14    Driver George Russell was given a 5 second tim...                 Race
# ...                                                 ...                  ...
# 1139  Driver George Russell received a 5-second time...                 Race
# 1152  Provisional race classification after 56 laps,...                  NaN
# 1153  Provisional Starting Grid for the event, listi...                  NaN
# 1155  Lap times deleted due to cars leaving the trac...           Qualifying
# 1156  Cars did not use the track at turns 6, 9, 11, ...                  NaN
#
#                         track lap_number turn_number  \
# 9          Yas Marina Circuit        NaN         NaN
# 10         Yas Marina Circuit        NaN         NaN
# 12                        NaN        NaN         NaN
# 13                        NaN        NaN         NaN
# 14                        NaN        NaN         NaN
# ...                       ...        ...         ...
# 1139                      NaN        NaN           1
# 1152  Circuit of The Americas         56         NaN
# 1153                      NaN        NaN         NaN
# 1155           Austin Circuit        NaN  T9,T12,T19
# 1156           Austin Circuit        NaN         NaN
#
#      safety_car_or_vsc_involved  \
# 9                           NaN
# 10                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# ...                         ...
# 1139                        NaN
# 1152                        NaN
# 1153                        NaN
# 1155                        NaN
# 1156                        NaN
#
#                                           penalty_given  \
# 9     5 second time penalty - Causing a collision - ...
# 10                              Grid penalty (3 places)
# 12                                                 €500
# 13    5 second time penalty, 2 penalty points (total...
# 14                                            5 seconds
# ...                                                 ...
# 1139                        5 seconds, 2 penalty points
# 1152  [{'car_number': 10, 'type_of_penalty': 'Time p...
# 1153  ['5 place grid penalty', '10 place grid penalty']
# 1155                              Deletion of lap times
# 1156                      Disqualification from results
#
#                                        type_of_incident was_contact_made  \
# 9                                                   NaN              NaN
# 10                                  Causing a collision              NaN
# 12                                 Speeding in pit lane              NaN
# 13                                            Collision              Yes
# 14                                       Unsafe release              Yes
# ...                                                 ...              ...
# 1139                                          Collision              Yes
# 1152                                                NaN              NaN
# 1153                                                NaN              NaN
# 1155  Breached Appendix L Ch IV Article 2 c) and Art...              NaN
# 1156  Breach of Appendix L, Ch IV Article 2 c) of th...              NaN
#
#      immediat_advantage_gained  \
# 9                          NaN
# 10                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# ...                        ...
# 1139                       NaN
# 1152                       NaN
# 1153                       NaN
# 1155                       NaN
# 1156                       NaN
#
#                                        drivers_invovled  \
# 9                                                   NaN
# 10                                 ['Daniel Ricciardo']
# 12                                   ['Lewis Hamilton']
# 13                ['Mick Schumacher', 'Nikita Mazepin']
# 14                            ['George Russell', 'NOR']
# ...                                                 ...
# 1139                      ['63 - George Russell', '55']
# 1152  [{'driver_number': 10, 'team': 'Scuderia Alpha...
# 1153  ['Carlos SAINZ', 'Max VERSTAPPEN', 'Lewis HAMI...
# 1155  ['Zhou Guanyu', 'Lewis Hamilton', 'Sebastian V...
# 1156  ['Alexander Albon', 'Pierre Gasly', 'Fernando ...
#
#                                          teams_invovled  \
# 9                                                   NaN
# 10           ['McLaren F1 Team', 'Scuderia AlphaTauri']
# 12                    ['Mercedes-AMG Petronas F1 Team']
# 13                                     ['Haas F1 Team']
# 14                    ['Mercedes-AMG Petronas F1 Team']
# ...                                                 ...
# 1139                  ['Mercedes-AMG Petronas F1 Team']
# 1152  ['Alpine', 'Aston Martin Aramco Cognizant F1 T...
# 1153  ['Scuderia Ferrari', 'Oracle Red Bull Racing',...
# 1155  Appendix L Ch IV Article 2 c) of the FIA Inter...
# 1156  Appendix L, Ch IV Article 2 c) of the FIA Inte...
#
#                                           rule_violated  \
# 9                                                   NaN
# 10                                                  NaN
# 12    Article 34.7 of the FIA Formula One Sporting R...
# 13    Appendix L Chapter IV 2 d) of the FIA Internat...
# 14    Article 34.14 a) of the FIA Formula One Sporti...
# ...                                                 ...
# 1139  Article 2 d) Chapter IV Appendix L of the FIA ...
# 1152                                                NaN
# 1153                                                NaN
# 1155  Received timing information, report from the R...
# 1156  Stewards received timing information, a report...
#
#                                          decision_notes  \
# 9                                                   NaN
# 10    Stewards' document no. 58 (2022 São Paulo Gran...
# 12      Exceeding the pit lane speed limit by 4.5 km/h.
# 13    The driver of Car 47 braked too late into Turn...
# 14    Reviewing video evidence, the Stewards determi...
# ...                                                 ...
# 1139  Review of video evidence determined driver to ...
# 1152                                                NaN
# 1153  Additional power unit elements have been used ...
# 1155  2022 United States Grand Prix - Qualifying Del...
# 1156  2022 United States Grand Prix - Race Deleted L...
#
#                                             source_file
# 9     2022 Abu Dhabi Grand Prix - Final Race Classif...
# 10    2022 Abu Dhabi Grand Prix - Final Starting Gri...
# 12    2022 Abu Dhabi Grand Prix - Offence - Car 44 -...
# 13    2022 Abu Dhabi Grand Prix - Offence - Car 47 -...
# 14    2022 Abu Dhabi Grand Prix - Offence - Car 63 -...
# ...                                                 ...
# 1139  2022 United States Grand Prix - Offence - Car ...
# 1152  2022 United States Grand Prix - Provisional Ra...
# 1153  2022 United States Grand Prix - Provisional St...
# 1155                                                NaN
# 1156                                                NaN
#
# [280 rows x 18 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Load your CSV file
df24 = pd.read_csv(r"file loc")

# %%
# Check missing values per column
print("=== Missing Values Per Column ===")
print(df24.isnull().sum())
print("\n")
# Out:
# === Missing Values Per Column ===
# type_of_document                 0
# year                           104
# grand_prix                       2
# description                     34
# session_type                   862
# track                          671
# lap_number                    1489
# turn_number                   1387
# safety_car_or_vsc_involved    1429
# penalty_given                 1182
# type_of_incident               956
# was_contact_made              1389
# immediate_advantage_gained    1498
# drivers_involved               432
# teams_involved                 496
# rule_violated                  820
# decision_notes                 238
# source_file                    346
# dtype: int64

# %%
penalty_df24 = df24[
    df24['penalty_given'].notnull() &
    df24['description'].notnull()
].copy()


print("\n=== Penalty DataFrame Info ===")
print(penalty_df24.info())
print(penalty_df24)
penalty_df24.to_csv("penalty24_data.csv", index=False)
# Out:
# === Penalty DataFrame Info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 327 entries, 21 to 1482
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   type_of_document            327 non-null    object
#  1   year                        301 non-null    object
#  2   grand_prix                  327 non-null    object
#  3   description                 327 non-null    object
#  4   session_type                259 non-null    object
#  5   track                       95 non-null     object
#  6   lap_number                  11 non-null     object
#  7   turn_number                 66 non-null     object
#  8   safety_car_or_vsc_involved  24 non-null     object
#  9   penalty_given               327 non-null    object
#  10  type_of_incident            269 non-null    object
#  11  was_contact_made            53 non-null     object
#  12  immediate_advantage_gained  6 non-null      object
#  13  drivers_involved            314 non-null    object
#  14  teams_involved              305 non-null    object
#  15  rule_violated               255 non-null    object
#  16  decision_notes              293 non-null    object
#  17  source_file                 294 non-null    object
# dtypes: object(18)
# memory usage: 48.5+ KB
# None
#                  type_of_document  year                grand_prix  \
# 21              Stewards decision  2024      Abu Dhabi Grand Prix
# 22    Stewards' Decision Document  2024      Abu Dhabi Grand Prix
# 23              Stewards decision  2024      Abu Dhabi Grand Prix
# 24             Steward's decision  2024      Abu Dhabi Grand Prix
# 25              Stewards decision  2024      Abu Dhabi Grand Prix
# ...                           ...   ...                       ...
# 1457            Stewards decision  2024  United States Grand Prix
# 1468    Technical delegate report  2024  United States Grand Prix
# 1478           Stewards' decision   NaN  United States Grand Prix
# 1479           Stewards' decision   NaN  United States Grand Prix
# 1482            Stewards Document  2024  United States Grand Prix
#
#                                             description       session_type  \
# 21    Final Race Classification with timing sheet an...                NaN
# 22    Final Starting Grid with grid penalties applie...                NaN
# 23    Driver Max Verstappen from Oracle Red Bull Rac...               Race
# 24    Ferrari driver Charles Leclerc penalized for b...         Practice 1
# 25    Driver Lance Stroll found guilty of leaving th...               Race
# ...                                                 ...                ...
# 1457  Cars did not use the track at turns 1, 9, 12 a...  Sprint Qualifying
# 1468  Changes made by the Williams Racing team to ca...                NaN
# 1478  Provisional Race Classification after 56 laps,...                NaN
# 1479  5 second time penalty applied to car 81 as per...                NaN
# 1482  Provisional Starting Grid, detailing driver po...                NaN
#
#                         track lap_number turn_number  \
# 21         Yas Marina Circuit        NaN         NaN
# 22         Yas Marina Circuit        NaN         NaN
# 23                        NaN        NaN           1
# 24         Yas Marina Circuit        NaN         NaN
# 25                        NaN        NaN         NaN
# ...                       ...        ...         ...
# 1457  Circuit of The Americas        NaN         NaN
# 1468                      NaN        NaN         NaN
# 1478                      NaN        NaN         NaN
# 1479                      NaN        NaN         NaN
# 1482                      NaN        NaN         NaN
#
#      safety_car_or_vsc_involved  \
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# ...                         ...
# 1457                        NaN
# 1468                        NaN
# 1478                        NaN
# 1479                        NaN
# 1482                        NaN
#
#                                           penalty_given  \
# 21             ['5 second time penalty - Track limits']
# 22    ["5 place grid penalty - Additional RNC have b...
# 23             10 second time penalty, 2 penalty points
# 24    Drop of 10 grid positions for the next Race in...
# 25                                5 second time penalty
# ...                                                 ...
# 1457  Deletion of lap times in accordance with Artic...
# 1468              Relegation to pit lane for the Sprint
# 1478                              5 second time penalty
# 1479                              5 second time penalty
# 1482  ["Car 30 - Required to start from the back of ...
#
#                                        type_of_incident was_contact_made  \
# 21                                                  NaN              NaN
# 22                                                  NaN              NaN
# 23                                            Collision             TRUE
# 24                                         Infringement              NaN
# 25       Leaving the track without a justifiable reason              NaN
# ...                                                 ...              ...
# 1457                                       Infringement              NaN
# 1468  Rule violation: non-compliance with Technical ...              NaN
# 1478                                                NaN              NaN
# 1479                                            Contact             TRUE
# 1482                                                NaN              NaN
#
#      immediate_advantage_gained  \
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# ...                         ...
# 1457                        NaN
# 1468                        NaN
# 1478                        NaN
# 1479                        NaN
# 1482                        NaN
#
#                                        drivers_involved  \
# 21    ['Lando Norris', 'Carlos Sainz', 'Charles Lecl...
# 22    ['Lando NORRIS', 'Oscar PIASTRI', 'Carlos SAIN...
# 23    ['Max Verstappen', 'Felix Holter', 'Loïc Bacqu...
# 24                                  ['Charles Leclerc']
# 25                                     ['Lance Stroll']
# ...                                                 ...
# 1457  ['Sergio Perez', 'Oscar Piastri', 'Fernando Al...
# 1468                                ['Alexander Albon']
# 1478                                 ['Lewis Hamilton']
# 1479                                               [81]
# 1482  Lando NORRIS, Max VERSTAPPEN, Carlos SAINZ, Ch...
#
#                                          teams_involved  \
# 21                                                  NaN
# 22    ['McLaren Formula 1 Team', 'Scuderia Ferrari',...
# 23    Appendix L, Chapter IV, Article 2 d) of the FI...
# 24                                 ['Scuderia Ferrari']
# 25                      ['Aston Martin Aramco F1 Team']
# ...                                                 ...
# 1457  ['Red Bull Racing', 'McLaren Formula 1 Team', ...
# 1468                                ['Williams Racing']
# 1478                                                 []
# 1479                         ['Oracle Red Bull Racing']
# 1482  ['McLaren Formula 1 Team', 'Oracle Red Bull Ra...
#
#                                           rule_violated  \
# 21                                       None provided.
# 22                                                  NaN
# 23    The Stewards reviewed video and in-car video e...
# 24    Article 28.2 of the FIA Formula One Sporting R...
# 25    Article 33.3 of the FIA Formula One Sporting R...
# ...                                                 ...
# 1457  Breach of Appendix L Chapter IV Article 2 c) o...
# 1468  Article 40.9 of the 2024 Formula One Sporting ...
# 1478                                                NaN
# 1479  Article 27.1 (c) of the FIA Formula One Sporti...
# 1482                                                NaN
#
#                                          decision_notes  \
# 21    2024 Abu Dhabi Grand Prix - Final Race Classif...
# 22              Grid penalties applied to certain cars.
# 23    2024 Abu Dhabi Grand Prix - Infringement - Car...
# 24    The penalty is imposed in accordance with Arti...
# 25    Video evidence showed that Car 18 left the tra...
# ...                                                 ...
# 1457  Stewards considered the matter and determined ...
# 1468  Changes made without approval from the FIA tec...
# 1478  Leaving the track and gaining an advantage; Fo...
# 1479                   Paul Walter, Clerk of the Course
# 1482  Additional penalties for teams using additiona...
#
#                                             source_file
# 21                                                  NaN
# 22    2024 Abu Dhabi Grand Prix - Final Starting Gri...
# 23                                                  NaN
# 24    2024 Abu Dhabi Grand Prix - Infringement - Car...
# 25    2024 Abu Dhabi Grand Prix - Infringement - Car...
# ...                                                 ...
# 1457  2024 United States Grand Prix - Infringement -...
# 1468  2024 United States Grand Prix - Parc Fermé Iss...
# 1478  2024 United States Grand Prix - Provisional Ra...
# 1479  2024 United States Grand Prix - Provisional Sp...
# 1482  2024 United States Grand Prix - Provisional St...
#
# [327 rows x 18 columns]

# %%
# Load your CSV file
df25 = pd.read_csv(r"file location")

# %%
# Check missing values per column
print("=== Missing Values Per Column ===")
print(df25.isnull().sum())
print("\n")
# Out:
# === Missing Values Per Column ===
# type_of_document                0
# year                           19
# grand_prix                      3
# description                    50
# session_type                  426
# track                         431
# lap_number                    727
# turn_number                   661
# safety_car_or_vsc_involved    700
# penalty_given                 579
# type_of_incident              478
# was_contact_made              681
# immediate_advantage_gained    728
# drivers_involved              249
# teams_involved                251
# rule_violated                 393
# decision_notes                184
# source_file                   147
# dtype: int64

# %%
penalty_df25 = df25[
    df25['penalty_given'].notnull() &
    df25['description'].notnull()
].copy()


print("\n=== Penalty DataFrame Info ===")
print(penalty_df25.info())
print(penalty_df25)
penalty_df25.to_csv("penalty25_data.csv", index=False)
# Out:
# === Penalty DataFrame Info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 168 entries, 2 to 732
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   type_of_document            168 non-null    object
#  1   year                        164 non-null    object
#  2   grand_prix                  168 non-null    object
#  3   description                 168 non-null    object
#  4   session_type                133 non-null    object
#  5   track                       42 non-null     object
#  6   lap_number                  13 non-null     object
#  7   turn_number                 44 non-null     object
#  8   safety_car_or_vsc_involved  14 non-null     object
#  9   penalty_given               168 non-null    object
#  10  type_of_incident            142 non-null    object
#  11  was_contact_made            35 non-null     object
#  12  immediate_advantage_gained  15 non-null     object
#  13  drivers_involved            160 non-null    object
#  14  teams_involved              153 non-null    object
#  15  rule_violated               131 non-null    object
#  16  decision_notes              145 non-null    object
#  17  source_file                 157 non-null    object
# dtypes: object(18)
# memory usage: 24.9+ KB
# None
#                               type_of_document  year             grand_prix  \
# 2                           Steward's decision  2025  Australian Grand Prix
# 3                           Steward's decision  2025  Australian Grand Prix
# 13                          Stewards' decision  2025  Australian Grand Prix
# 14                          Stewards' decision  2025  Australian Grand Prix
# 15                           Stewards Decision  2025  Australian Grand Prix
# ..                                         ...   ...                    ...
# 715                          Stewards Decision  2025     Spanish Grand Prix
# 716                          Stewards decision  2025     Spanish Grand Prix
# 724                Technical Delegate’s Report  2025     Spanish Grand Prix
# 730  Media delegate note / procedural document  2025     Spanish Grand Prix
# 732                          Stewards Document  2025     Spanish Grand Prix
#
#                                            description session_type  \
# 2    Driver failed to maintain a 10 car-length dist...         Race
# 3    Driver failed to maintain a 10 car-length dist...         Race
# 13   Final Race Classification after 57 Laps - 300....          NaN
# 14   DRIVERS REQUIRED TO START FROM THE PIT LANE; C...          NaN
# 15   Driver Andrea Kimi Antonelli released into the...         Race
# ..                                                 ...          ...
# 715  Deletion of qualifying lap times for drivers w...   Qualifying
# 716  Lap times deleted for multiple drivers for not...         Race
# 724  Oracle Red Bull Racing replaced the rear wing ...         Race
# 730  Pre-Race Procedure, including timings for driv...         Race
# 732                    Provisional Race Classification         Race
#
#          track lap_number   turn_number safety_car_or_vsc_involved  \
# 2          NaN        NaN           NaN                       True
# 3          NaN        NaN           NaN                       True
# 13   Melbourne        NaN           NaN                        NaN
# 14         NaN        NaN           NaN                        NaN
# 15         NaN        NaN           NaN                        NaN
# ..         ...        ...           ...                        ...
# 715        NaN        NaN      2 and 10                        NaN
# 716        NaN        NaN  2, 5, 10, 13                        NaN
# 724        NaN        NaN           NaN                        NaN
# 730        NaN        NaN           NaN                        NaN
# 732  Barcelona         66           NaN                        NaN
#
#                                          penalty_given  \
# 2                                   No penalty applied
# 3                                   No penalty applied
# 13   2 second time penalty - Unsafe Release - Resci...
# 14                 Required to start from the pit lane
# 15                                           5 seconds
# ..                                                 ...
# 715                              Deletion of lap times
# 716                              Deletion of lap times
# 724                            start from the pit lane
# 730                   Will be reported to the Stewards
# 732  Car 87 - 10 second time penalty applied as per...
#
#                                       type_of_incident was_contact_made  \
# 2                                         Infringement              NaN
# 3    Breach of Article 55.7 of the FIA Formula One ...              NaN
# 13                                                 NaN              NaN
# 14                                                 NaN              NaN
# 15                                        Infringement             True
# ..                                                 ...              ...
# 715                                       Track limits              NaN
# 716                                       Track limits              NaN
# 724                                                NaN              NaN
# 730                                                NaN              NaN
# 732  Leaving the track and gaining an advantage, Ca...              NaN
#
#     immediate_advantage_gained  \
# 2                          NaN
# 3                          NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# ..                         ...
# 715                        NaN
# 716                        NaN
# 724                        NaN
# 730                        NaN
# 732               yes (car 87)
#
#                                       drivers_involved  \
# 2                                  ['Fernando Alonso']
# 3                                     ['Yuki Tsunoda']
# 13   Lando NORRIS, Max VERSTAPPEN, George RUSSELL, ...
# 14           87 Oliver BEARMAN, MoneyGram Haas F1 Team
# 15                 ['Andrea Kimi Antonelli', 'Car 27']
# ..                                                 ...
# 715                  Franco Colapinto, Fernando Alonso
# 716  Franco Colapinto, Fernando Alonso, Kimi Antone...
# 724                                                NaN
# 730                                                NaN
# 732  ['Oscar PIASTRI', 'Lando NORRIS', 'Charles LEC...
#
#                                         teams_involved  \
# 2                      ['Aston Martin Aramco F1 Team']
# 3               ['Visa Cash App Racing Bulls F1 Team']
# 13   McLaren Formula 1 Team, Oracle Red Bull Racing...
# 14                              MoneyGram Haas F1 Team
# 15                   ['Mercedes-AMG PETRONAS F1 Team']
# ..                                                 ...
# 715    BWT Alpine F1 Team, Aston Martin Aramco F1 Team
# 716  BWT Alpine F1 Team, Aston Martin Aramco F1 Tea...
# 724                         ['Oracle Red Bull Racing']
# 730                                                NaN
# 732  ['McLaren Formula 1 Team', 'Scuderia Ferrari H...
#
#                                          rule_violated  \
# 2    Article 55.7 of the FIA Formula One Sporting R...
# 3    Article 55.7 of the FIA Formula One Sporting R...
# 13                                                 NaN
# 14                                                 NaN
# 15   Article 34.14 a) of the FIA Formula One Sporti...
# ..                                                 ...
# 715  Appendix L Chapter IV Article 2 c) of the FIA ...
# 716  Appendix L Chapter IV Article 2 c) of the FIA ...
# 724  Article 40.9 a) of the 2025 Formula One Sporti...
# 730  article 19.4.b) of the FIA Formula One Sportin...
# 732                                                NaN
#
#                                         decision_notes  \
# 2    Mitigating circumstances due to weather condit...
# 3    Reviewing positioning/marshalling system data,...
# 13                                                 NaN
# 14   Car modified whilst under Parc Fermé condition...
# 15   Video and in-car video evidence reviewed to de...
# ..                                                 ...
# 715  Cars did not use the track at turns 2 and 10. ...
# 716  Lap times deleted in accordance with Article 1...
# 724  Car number 22 should start the Race from the p...
# 730  Summary of requirements for Pre-Race activitie...
# 732                                                NaN
#
#                                            source_file
# 2    2025_australian_grand_prix_-_decision_-_car_14...
# 3    2025_australian_grand_prix_-_decision_-_car_22...
# 13   2025_australian_grand_prix_-_final_race_classi...
# 14   2025_australian_grand_prix_-_final_starting_gr...
# 15   2025_australian_grand_prix_-_infringement_-_ca...
# ..                                                 ...
# 715  2025_spanish_grand_prix_-_infringement_-_quali...
# 716  2025_spanish_grand_prix_-_infringement_-_race_...
# 724    2025_spanish_grand_prix_-_parc_ferme_issues.txt
# 730   2025_spanish_grand_prix_-_pre-race_procedure.txt
# 732  2025_spanish_grand_prix_-_provisional_race_cla...
#
# [168 rows x 18 columns]
